# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
df = pd.read_csv("Jupiter_DETECTIONS_IV.csv")
arr = df.to_numpy()
df["datetime"] = pd.to_datetime(df["ts"], format="%Y%m%d_%H%M%S")
df["Date"] = df["datetime"].dt.date
df["Time"] = df["datetime"].dt.time
pd.set_option('display.max_columns', None)
df.head()
# Out:
#       Body        Date   Band Category  Freq_MHz  \
# 0  Jupiter  2025-01-11   Blue    10min      73.0
# 1  Jupiter  2025-01-11    Red    10min      27.0
# 2  Jupiter  2024-12-18  69MHz    10min      69.0
# 3  Jupiter  2024-12-19  27MHz    10min      27.0
# 4  Jupiter  2024-12-19  59MHz    10min      59.0
#
#                                   base  I_Peak_Jy  I_Peak_SNR  I_Offset_am  \
# 0  Jupiter_73MHz_10min_20250111_060857   4.538348    6.038900     2.220000
# 1  Jupiter_27MHz_10min_20250111_095830   6.883836    2.535663     6.508211
# 2  Jupiter_69MHz_10min_20241218_083323   4.104297    5.296948     1.875000
# 3  Jupiter_27MHz_10min_20241219_070924  35.029911    4.969982     2.651650
# 4  Jupiter_59MHz_10min_20241219_071916   5.658505    5.631384     1.875000
#
#    V_Peak_Jy  V_Peak_SNR  V_Offset_am  Det_I  Det_V  Det_either  \
# 0  -0.165186    1.567358     3.139554   True  False        True
# 1   3.029238    7.769114     6.508211  False   True        True
# 2  -0.234873    1.531057     2.651650   True  False        True
# 3  30.543440   20.851655     2.651650  False   True        True
# 4  -0.282171    1.734251     2.651650   True  False        True
#
#                 ts  I_RMS_Jy  V_RMS_Jy  V_RMS_ann V_conf    I_conf    I_pk_RA  \
# 0  20250111_060857  0.751519  0.160397   0.105391    NaN     solid  70.471171
# 1  20250111_095830  2.714807  1.223046   0.389908  solid       NaN        NaN
# 2  20241218_083323  0.774842  0.210756   0.153406    NaN  marginal  73.242110
# 3  20241219_070924  7.048298  8.129708   1.464797  solid       NaN        NaN
# 4  20241219_071916  1.004816  0.182816   0.162705    NaN  marginal  73.163633
#
#     I_pk_Dec  VLSS_I_sep_beam  VLSS_I_flux_Jy    V_pk_RA   V_pk_Dec  \
# 0  21.627940         2.485764            1.40        NaN        NaN
# 1        NaN              NaN             NaN  70.594340  21.645005
# 2  21.881660         2.801415            0.85        NaN        NaN
# 3        NaN              NaN             NaN  73.161498  21.921293
# 4  21.888994         2.895367            0.90        NaN        NaN
#
#    VLSS_V_sep_beam  VLSS_V_flux_Jy  VLSS_bg_I  VLSS_bg_V  VLSS_background  \
# 0              NaN             NaN      False      False            False
# 1         0.968251             1.4      False      False            False
# 2              NaN             NaN      False      False            False
# 3         1.206532             0.9      False      False            False
# 4              NaN             NaN      False      False            False
#
#    VLSS_bg_flux_Jy VLSS_warning            datetime      Time
# 0              NaN          NaN 2025-01-11 06:08:57  06:08:57
# 1              NaN          NaN 2025-01-11 09:58:30  09:58:30
# 2              NaN          NaN 2024-12-18 08:33:23  08:33:23
# 3              NaN          NaN 2024-12-19 07:09:24  07:09:24
# 4              NaN          NaN 2024-12-19 07:19:16  07:19:16

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, HourLocator
from datetime import datetime

def plot_day(df, date_str, show_plot=True, filename_out=False):
    day_df = df[df['Date'] == datetime.strptime(date_str, "%Y-%m-%d").date()].copy()
    if day_df.empty:
        print(f"No data found for {date_str}")
        return

    day_df['datetime'] = pd.to_datetime(day_df['datetime'])
    day_df = day_df.sort_values('datetime')
    freqs = sorted(day_df['Freq_MHz'].unique())

    fixed_num_rows = 3
    fixed_num_cols = 5

    fig, axes = plt.subplots(
        fixed_num_rows, fixed_num_cols,
        figsize=(15, fixed_num_rows * 3.5),
        sharex=False
    )
    axes_flat = axes.flatten()

    fig.suptitle(f"Jupiter Emission on {date_str}", fontsize=20, y=0.98)
    fig.text(0.5, 0.93, "Stokes I_Peak_Jy and V_Peak_Jy", ha='center', fontsize=14)

    hour_fmt = DateFormatter('%H')
    hour_locator = HourLocator(interval=1)

    day_start = datetime.strptime(date_str, "%Y-%m-%d").replace(hour=3, minute=0, second=0)
    day_end   = datetime.strptime(date_str, "%Y-%m-%d").replace(hour=12, minute=0, second=0)

    for i, freq in enumerate(freqs):
        if i >= len(axes_flat):
            print(f"Warning: More frequencies ({len(freqs)}) than available subplots.")
            break

        ax = axes_flat[i]
        sub = day_df[day_df['Freq_MHz'] == freq]

        ax.plot(sub['datetime'], sub['I_Peak_Jy'], label='Stokes I',
                color='tab:blue', marker='o', ms=4)
        ax.plot(sub['datetime'], sub['V_Peak_Jy'], label='Stokes V',
                color='tab:red', marker='o', ms=4)

        ax.set_ylabel(f"{freq} MHz (Jy)")
        ax.grid(True, alpha=0.3)
        ax.legend(loc='upper right', fontsize='small')

        ax.set_xlim(day_start, day_end)
        ax.xaxis.set_major_locator(hour_locator)
        ax.xaxis.set_major_formatter(hour_fmt)
        ax.tick_params(axis='x', labelrotation=0)

    for j in range(len(freqs), len(axes_flat)):
        axes_flat[j].set_visible(False)

    for ax in axes_flat:
        if ax.get_visible():
            ax.set_xlabel("Hour (UTC)")

    plt.tight_layout(rect=[0, 0, 1, 0.94])

    if show_plot:
        plt.show()
    if filename_out:
        plt.savefig(filename_out)

# %%
from datetime import datetime

date_string = "2023-10-27"
datetime_object = datetime.strptime(date_string, "%Y-%m-%d")

print(f"Original string: {date_string}")
print(f"Converted datetime object: {datetime_object}")
print(f"Type of converted object: {type(datetime_object)}")
# Out:
# Original string: 2023-10-27
# Converted datetime object: 2023-10-27 00:00:00
# Type of converted object: <class 'datetime.datetime'>

# %%
import os

output_folder = "jupiter_plots"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created directory: {output_folder}")

# %%
import os

output_folder = "jupiter_plots" # Ensure this variable is defined if not already

unique_dates = df['Date'].unique()
print("Generating plots for unique dates...")
for date in unique_dates:
    This_Date_str = date.strftime("%Y-%m-%d")
    # Prepend the output folder to the filename
    filename = os.path.join(output_folder, f"Jupiter_Emission_{This_Date_str}.png")
    print(f"Saving plot for {This_Date_str} to {filename}")
    plot_day(df, This_Date_str, show_plot=False, filename_out=filename)
print("All plots saved.")
# Out:
# Generating plots for unique dates...
# Saving plot for 2025-01-11 to jupiter_plots/Jupiter_Emission_2025-01-11.png
# Saving plot for 2024-12-18 to jupiter_plots/Jupiter_Emission_2024-12-18.png
# Saving plot for 2024-12-19 to jupiter_plots/Jupiter_Emission_2024-12-19.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10169/761855825.py in <cell line: 0>()
#      10     filename = os.path.join(output_folder, f"Jupiter_Emission_{This_Date_str}.png")
#      11     print(f"Saving plot for {This_Date_str} to {filename}")
# ---> 12     plot_day(df, This_Date_str, show_plot=False, filename_out=filename)
#      13 print("All plots saved.")
#
# /tmp/ipykernel_10169/2978160609.py in plot_day(df, date_str, show_plot, filename_out)
#      62             ax.set_xlabel("Hour (UTC)")
#      63
# ---> 64     plt.tight_layout(rect=[0, 0, 1, 0.94])
#      65
#      66     if show_plot:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    2833     rect: tuple[float, float, float, float] | None = None,
#    2834 ) -> None:
# -> 2835     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2836
#    2837
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3638             previous_engine = self.get_layout_engine()
#    3639             self.set_layout_engine(engine)
# -> 3640             engine.execute(self)
#    3641             if previous_engine is not None and not isinstance(
#    3642                 previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/layout_engine.py in execute(self, fig)
#     181         renderer = fig._get_renderer()
#     182         with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183             kwargs = get_tight_layout_figure(
#     184                 fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185                 pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     264             slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
#     265
# --> 266     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                       shape=(max_nrows, max_ncols),
#     268                                       span_pairs=span_pairs,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_tight_layout.py in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80         for ax in subplots:
#      81             if ax.get_visible():
# ---> 82                 bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      83
#      84         tight_bbox_raw = Bbox.union(bb)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1400     """
#    1401     try:
# -> 1402         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403     except TypeError:
#    1404         return obj.get_tightbbox(*args, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4540
#    4541         for a in bbox_artists:
# -> 4542             bbox = a.get_tightbbox(renderer)
#    4543             if (bbox is not None
#    4544                     and 0 < bbox.width < np.inf
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/legend.py in get_tightbbox(self, renderer)
#    1057     def get_tightbbox(self, renderer=None):
#    1058         # docstring inherited
# -> 1059         return self._legend_box.get_window_extent(renderer)
#    1060
#    1061     def get_frame_on(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in get_window_extent(self, renderer)
#     365         if renderer is None:
#     366             renderer = self.get_figure(root=True)._get_renderer()
# --> 367         bbox = self.get_bbox(renderer)
#     368         try:  # Some subclasses redefine get_offset to take no args.
#     369             px, py = self.get_offset(bbox, renderer)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in get_bbox(self, renderer)
#     358     def get_bbox(self, renderer):
#     359         """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360         bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361         return bbox
#     362
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in _get_bbox_and_child_offsets(self, renderer)
#     450                     c.set_width(self.width)
#     451
# --> 452         bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     453         (x0, x1), xoffsets = _get_aligned_offsets(
#     454             [bbox.intervalx for bbox in bboxes], self.width, self.align)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in get_bbox(self, renderer)
#     358     def get_bbox(self, renderer):
#     359         """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360         bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361         return bbox
#     362
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in _get_bbox_and_child_offsets(self, renderer)
#     477         sep = self.sep * dpicor
#     478
# --> 479         bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     480         if not bboxes:
#     481             return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in get_bbox(self, renderer)
#     358     def get_bbox(self, renderer):
#     359         """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360         bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361         return bbox
#     362
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in _get_bbox_and_child_offsets(self, renderer)
#     450                     c.set_width(self.width)
#     451
# --> 452         bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     453         (x0, x1), xoffsets = _get_aligned_offsets(
#     454             [bbox.intervalx for bbox in bboxes], self.width, self.align)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in get_bbox(self, renderer)
#     358     def get_bbox(self, renderer):
#     359         """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 360         bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     361         return bbox
#     362
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in _get_bbox_and_child_offsets(self, renderer)
#     477         sep = self.sep * dpicor
#     478
# --> 479         bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     480         if not bboxes:
#     481             return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/offsetbox.py in get_bbox(self, renderer)
#     765             ismath="TeX" if self._text.get_usetex() else False)
#     766
# --> 767         bbox, info, yd = self._text._get_layout(renderer)
#     768         w, h = bbox.size
#     769
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     443         xmin = corners_rotated[:, 0].min()
#     444         xmax = corners_rotated[:, 0].max()
# --> 445         ymin = corners_rotated[:, 1].min()
#     446         ymax = corners_rotated[:, 1].max()
#     447         width = xmax - xmin
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#      47           initial=_NoValue, where=True):
# ---> 48     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      49
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:
